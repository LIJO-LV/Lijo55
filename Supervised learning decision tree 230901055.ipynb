# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
df=pd.read_csv("Decision tree.csv")
print(df)
d={'UK':0,'USA':1,'N':2}
df['Nationality']=df['Nationality'].map(d)
d={'YES':1,'NO':0}
df['Go']=df['Go'].map(d)
features=['Age','Experience','Rank','Nationality']
x=df[features]
y=df['Go']
dtree=DecisionTreeClassifier()
dtree=dtree.fit(x,y)
tree.plot_tree(dtree,feature_names=features)
plt.show()
# Out:
#     Unnamed: 0  Age  Experience Nationality  Rank   Go
# 0            0   36          10          UK     9   NO
# 1            1   42          12         USA     4   NO
# 2            2   23           4           N     6  YES
# 3            3   52           4         USA     4   NO
# 4            4   43          21       INDIA     8   NO
# 5            5   44          14         USA     7  YES
# 6            6   66           3          UK     9   NO
# 7            7   35          14           N     5   NO
# 8            8   52          13           N     7  YES
# 9            9   35           5       INDIA     9   NO
# 10          10   24           3          UK     6   NO
# 11          11   18           3         USA     4  YES
# 12          12   45           9       INDIA     3   NO
